# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class MultiHeadVARAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadVARAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        
        self.depth = d_model // self.num_heads
        
        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)
        
        self.dense = tf.keras.layers.Dense(d_model)
    
    def split_heads(self, x, batch_size):
        """Split the last dimension into (num_heads, depth).
        Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
        """
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])
    
    def call(self, query, key, value, mask):
        batch_size = tf.shape(query)[0]
        
        query = self.wq(query)  # (batch_size, seq_len, d_model)
        key = self.wk(key)      # (batch_size, seq_len, d_model)
        value = self.wv(value)  # (batch_size, seq_len, d_model)
        
        query = self.split_heads(query, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
        key = self.split_heads(key, batch_size)      # (batch_size, num_heads, seq_len_k, depth)
        value = self.split_heads(value, batch_size)  # (batch_size, num_heads, seq_len_v, depth)
        
        # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
        # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
        scaled_attention, attention_weights = scaled_dot_product_attention(
            query, key, value, mask)
        
        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)
        
        concat_attention = tf.reshape(scaled_attention, 
                                      (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)
        
        output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
        
        return output, attention_weights
# Out:
# WARNING:tensorflow:Gradients do not exist for variables ['transformer/transformer_encoder/embedding/embeddings:0', 'dense_4/kernel:0', 'dense_4/bias:0', 'dense_5/kernel:0', 'dense_5/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/bias:0', 'dense_13/kernel:0', 'dense_13/bias:0', 'dense_14/kernel:0', 'dense_14/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/bias:0', 'dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/bias:0', 'dense_31/kernel:0', 'dense_31/bias:0', 'dense_32/kernel:0', 'dense_32/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/beta:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/kernel:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/bias:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/key/kernel:0', 't ...
# WARNING:tensorflow:Gradients do not exist for variables ['transformer/transformer_encoder/embedding/embeddings:0', 'dense_4/kernel:0', 'dense_4/bias:0', 'dense_5/kernel:0', 'dense_5/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/bias:0', 'dense_13/kernel:0', 'dense_13/bias:0', 'dense_14/kernel:0', 'dense_14/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/bias:0', 'dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/bias:0', 'dense_31/kernel:0', 'dense_31/bias:0', 'dense_32/kernel:0', 'dense_32/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/beta:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/kernel:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/bias:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/key/kernel:0', 't ...
# Epoch 1 Batch 0 Loss 8.984495162963867
# WARNING:tensorflow:Gradients do not exist for variables ['transformer/transformer_encoder/embedding/embeddings:0', 'dense_4/kernel:0', 'dense_4/bias:0', 'dense_5/kernel:0', 'dense_5/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/bias:0', 'dense_13/kernel:0', 'dense_13/bias:0', 'dense_14/kernel:0', 'dense_14/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/bias:0', 'dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/bias:0', 'dense_31/kernel:0', 'dense_31/bias:0', 'dense_32/kernel:0', 'dense_32/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/beta:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/kernel:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/bias:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/key/kernel:0', 't ...
# WARNING:tensorflow:Gradients do not exist for variables ['transformer/transformer_encoder/embedding/embeddings:0', 'dense_4/kernel:0', 'dense_4/bias:0', 'dense_5/kernel:0', 'dense_5/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/bias:0', 'dense_13/kernel:0', 'dense_13/bias:0', 'dense_14/kernel:0', 'dense_14/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/bias:0', 'dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/bias:0', 'dense_31/kernel:0', 'dense_31/bias:0', 'dense_32/kernel:0', 'dense_32/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/beta:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/kernel:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/bias:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/key/kernel:0', 't ...
# WARNING:tensorflow:Gradients do not exist for variables ['transformer/transformer_encoder/embedding/embeddings:0', 'dense_4/kernel:0', 'dense_4/bias:0', 'dense_5/kernel:0', 'dense_5/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/bias:0', 'dense_13/kernel:0', 'dense_13/bias:0', 'dense_14/kernel:0', 'dense_14/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/bias:0', 'dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/bias:0', 'dense_31/kernel:0', 'dense_31/bias:0', 'dense_32/kernel:0', 'dense_32/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/beta:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/kernel:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/bias:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/key/kernel:0', 't ...
# WARNING:tensorflow:Gradients do not exist for variables ['transformer/transformer_encoder/embedding/embeddings:0', 'dense_4/kernel:0', 'dense_4/bias:0', 'dense_5/kernel:0', 'dense_5/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/bias:0', 'dense_13/kernel:0', 'dense_13/bias:0', 'dense_14/kernel:0', 'dense_14/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/bias:0', 'dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/bias:0', 'dense_31/kernel:0', 'dense_31/bias:0', 'dense_32/kernel:0', 'dense_32/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/beta:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/kernel:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/bias:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/key/kernel:0', 't ...
# WARNING:tensorflow:Gradients do not exist for variables ['transformer/transformer_encoder/embedding/embeddings:0', 'dense_4/kernel:0', 'dense_4/bias:0', 'dense_5/kernel:0', 'dense_5/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/bias:0', 'dense_13/kernel:0', 'dense_13/bias:0', 'dense_14/kernel:0', 'dense_14/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/bias:0', 'dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/bias:0', 'dense_31/kernel:0', 'dense_31/bias:0', 'dense_32/kernel:0', 'dense_32/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/beta:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/kernel:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/bias:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/key/kernel:0', 't ...
# WARNING:tensorflow:Gradients do not exist for variables ['transformer/transformer_encoder/embedding/embeddings:0', 'dense_4/kernel:0', 'dense_4/bias:0', 'dense_5/kernel:0', 'dense_5/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer/layer_normalization_1/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_6/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_7/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer/frequency_attention/dense_8/bias:0', 'dense_13/kernel:0', 'dense_13/bias:0', 'dense_14/kernel:0', 'dense_14/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_2/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/layer_normalization_3/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_15/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_16/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_1/frequency_attention_1/dense_17/bias:0', 'dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_4/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/layer_normalization_5/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_24/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_25/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/kernel:0', 'transformer/transformer_encoder/transformer_encoder_layer_2/frequency_attention_2/dense_26/bias:0', 'dense_31/kernel:0', 'dense_31/bias:0', 'dense_32/kernel:0', 'dense_32/bias:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_6/beta:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/gamma:0', 'transformer/transformer_encoder/transformer_encoder_layer_3/layer_normalization_7/beta:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/kernel:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/query/bias:0', 'transformer/transformer_decoder/transformer_decoder_layer/multi_head_attention_1/key/kernel:0', 't ...
